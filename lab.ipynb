# %%
# instantiate odoo environment
import odoo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # instantiate odoo environment
# ----> 2 import odoo
#
# ModuleNotFoundError: No module named 'odoo'
